# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#when we r not using jupyter notebook then use-> plt.show()->for printing the plot

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#functional method
plt.plot(x,y)

# %%
#when not using jupyter notebook
plt.plot(x,y)
plt.show()  -> No out cell

# %%
print('string') -> same as plt.show()
# Out:
# string

# %%
#for colour and linestyle
plt.plot(x,y,'r-')

# %%
plt.plot(x,y)
plt.xlabel('X label')
plt.ylabel('Ylabel')
plt.title('title')
# Out:
# Text(0.5,1,'title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
   #object oriented method

# %%
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('Set Title')
# Out:
# Text(0.5,1,'Set Title')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.15,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.8,0.15,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.5,0.15,0.1,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.5,0.15,0.1,0.9])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5,1,'SMALLER PLOT')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(x,y)

# %%
fig,axes=plt.subplots()
axes.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
#axes.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)
plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000138495E0908>,
# ...
#       dtype=object)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First Plot')
axes[1].plot(y,x)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5,1,'Second Plot')

# %%
#figure size aspect ratio and DPI->dots per inch or pixels per inch

# %%
fig=plt.figure(figsize=(8,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')
# Out:
# Text(0.5,0,'X')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.plot(y,x)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X squared')
ax.plot(x,x**3,label='X cubed')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X squared')
ax.plot(x,x**3,label='X cubed')
ax.legend()

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X squared')
ax.plot(x,x**3,label='X cubed')
ax.legend(loc=0)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X squared')
ax.plot(x,x**3,label='X cubed')
ax.legend(loc=10)
# for the position of legends number codes are available  Eg- loc=10 is for center and loc=0 is for best

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X squared')
ax.plot(x,x**3,label='X cubed')
ax.legend(loc=(0.1,0.1))

# %%
fig.savefig('my_picture.png',dpi=200  )

# %%
#setting colours etc.

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
#for color

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red')

# %%
#for linewidth or lw

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',linewidth=20)

# %%
# use alpha for transparency

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',linewidth=20,alpha=0.5)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',lw=3,alpha=0.5)

# %%
#linestyle

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',lw=3,linestyle='--')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',lw=3,linestyle='-')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',lw=3,linestyle='-.')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',lw=3,linestyle=':')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='red',lw=3,linestyle='steps')

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x)
# Out:
# 11

# %%
#marker ->use for these 11 points marker

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=1,ls='-',marker='o')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=1,ls='-',marker='+')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=1,ls='-',marker='2')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=1,ls='-',marker='+',markersize=18)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=1,ls='-',marker='o',markersize=20)

# %%
fig=plt.figure()
ax1=fig.add_axes([2,5,4,4])
ax2=fig.add_axes([2.4,6,3,3])
ax1.plot(x,y,color='purple',lw=3,ls='-',marker='o',markersize=20,
       markerfacecolor='yellow',markeredgewidth=3,markeredgecolor='red')

ax2.plot(x,y,color='red',lw=3,ls='-',marker='o',markersize=20,
       markerfacecolor='green',markeredgewidth=2,markeredgecolor='purple')

# %%
fig=plt.figure()
ax1=fig.add_axes([2,5,4,4])
ax1.plot(x,x**3,
         label='X3',color='purple',lw=3,ls='-',marker='o',markersize=20,
       markerfacecolor='yellow',markeredgewidth=3,markeredgecolor='red')

ax1.plot(x,x**4,
         label='X4',color='red',lw=3,ls='-',marker='o',markersize=20,
       markerfacecolor='green',markeredgewidth=2,markeredgecolor='purple')
ax1.legend(loc=10)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=4,ls='--')
ax.set_xlim([0,1])
#ax.set_ylim([0,2])
# Out:
# (0, 1)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=4,ls='--')
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)
